# %% [markdown]
# <div>
# <img src="https://drive.google.com/uc?export=view&id=1vK33e_EqaHgBHcbRV_m38hx6IkG0blK_" width="350"/>
# </div>
#
# #**Artificial Intelligence - MSc**
# CS6501 - MACHINE LEARNING AND APPLICATIONS
#
# ###Instructor: Enrique Naredo
# ###CS6501_Lab-0.12

# %% [markdown]
# # Matplotlib exercises

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem 6
# Bar plot of x and money below

# %%
#input
x = np.arange(4)
money = [1.5e5, 2.5e6, 5.5e6, 2.0e7]
plt.bar(x,money)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Problem 7
# Plot the graph of the function $\cos(8 x)$ in red and $x^2$ in blue for $x \in[0,1]$ and add the label "x" and "f(x)" to the respective columns using `fontsize` 14.

# %%
x = np.linspace(0,1,50)
y1 = np.cos(8*x)
y2 = x**2
plt.xlabel("x")
plt.ylabel("f(x)")
plt.plot(x,y1,'red')
plt.plot(x,y2,'blue')

# %% [markdown]
# # Problem 8
# Plot the graph of the function $\cos(8 x)$ in red and $x^2$ in blue for $x \in[0,1]$ and add a legend
# with labels "cos(8x)" and "$x^2$"

# %%
x = np.linspace(0,1,50)
y1 = np.cos(8*x)
y2 = x**2
plt.xlabel("x")
plt.ylabel("f(x)")

plt.plot(x,y1,'red',label="cos(8x)")
plt.plot(x,y2,'blue',label="x^2")
plt.legend()

# %% [markdown]
# # Problem 9
# Generate samples from the <a href="https://en.wikipedia.org/wiki/Laplace_distribution">Laplace distribution</a> (use `np.random.laplace(0,2,100)`), and then plot a histogram of the samples using 30 bins.

# %%
x=np.random.laplace(0,2,100)
plt.hist(x,bins=30)
# Out:
# (array([ 1.,  0.,  0.,  0.,  1.,  0.,  2.,  1.,  3.,  1.,  3.,  2.,  5.,
#          5.,  6., 13., 13., 10., 11.,  3.,  3.,  3.,  3.,  3.,  4.,  0.,
#          0.,  2.,  1.,  1.]),
#  array([-9.74993311, -9.16627088, -8.58260865, -7.99894642, -7.41528418,
#         -6.83162195, -6.24795972, -5.66429749, -5.08063525, -4.49697302,
#         -3.91331079, -3.32964856, -2.74598633, -2.16232409, -1.57866186,
#         -0.99499963, -0.4113374 ,  0.17232484,  0.75598707,  1.3396493 ,
#          1.92331153,  2.50697377,  3.090636  ,  3.67429823,  4.25796046,
#          4.84162269,  5.42528493,  6.00894716,  6.59260939,  7.17627162,
#          7.75993386]),
#  <a list of 30 Patch objects>)

# %% [markdown]
# # Problem 10
# Plot the graph of the 2D function $e^{-x^2-y^2}$  for $x,y \in[-3,3]$.

# %%
ax = plt.axes(projection='3d')
x=np.linspace(-3,3,50)
y=np.linspace(-3,3,50)
z=np.exp(-x**2-y**2)
ax.plot3D(x, y, z, 'gray')
